# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("./Quote-Equity-TATAMOTORS-EQ-08-03-2020-to-08-03-2022.csv")

# %%
data.head()
# Out:
#          Date  series    OPEN    HIGH     LOW   PREV. CLOSE     ltp   close   \
# 0  07-Mar-2022      EQ  401.75  401.75  387.50        417.25  395.75  394.00
# 1  04-Mar-2022      EQ  431.85  431.85  414.75        437.10  418.40  417.25
# 2  03-Mar-2022      EQ  458.50  458.50  435.00        447.60  437.90  437.10
# 3  02-Mar-2022      EQ  452.95  454.25  444.55        454.05  448.80  447.60
# 4  28-Feb-2022      EQ  445.00  457.35  440.45        459.75  453.95  454.05
#
#     vwap   52W H   52W L    VOLUME              VALUE   No of trades
# 0  394.41   536.7  268.45  44836205  17,684,025,650.05         645399
# 1  423.93   536.7  268.45  38765185  16,433,838,263.50         616081
# 2  443.17   536.7  268.45  29599672  13,117,748,918.25         391753
# 3  449.27   536.7  268.45  25791134  11,587,137,992.70         335482
# 4  452.40   536.7  268.45  34475468  15,596,569,802.85         355388

# %%
data.tail()
# Out:
#            Date  series    OPEN    HIGH     LOW   PREV. CLOSE     ltp   \
# 491  16-Mar-2020      EQ   85.60   87.65   82.20         89.75   82.60
# 492  13-Mar-2020      EQ   81.90   94.15   78.05         88.00   90.50
# 493  12-Mar-2020      EQ   91.10   94.90   84.10         98.90   88.95
# 494  11-Mar-2020      EQ  104.85  106.50   97.80        105.70   98.35
# 495  09-Mar-2020      EQ  109.00  109.85  104.25        114.20  104.90
#
#      close    vwap   52W H   52W L     VOLUME              VALUE   \
# 491   82.95   84.99  239.35   78.05   73707690   6,264,695,282.20
# 492   89.75   87.17  239.35   78.05  106153102   9,253,211,498.25
# 493   88.00   89.33  239.35   84.10  143551005  12,823,134,333.10
# 494   98.90  101.88  239.35   97.80  111148611  11,323,926,446.30
# 495  105.70  107.19  239.35  104.25   81550460   8,741,634,311.05
#
#      No of trades
# 491         280638
# 492         428426
# 493         483314
# 494         335274
# 495         284834

# %%
print(data.columns.tolist())
# Out:
# ['Date ', 'series ', 'OPEN ', 'HIGH ', 'LOW ', 'PREV. CLOSE ', 'ltp ', 'close ', 'vwap ', '52W H ', '52W L ', 'VOLUME ', 'VALUE ', 'No of trades ']

# %%
fig=plt.figure(figsize=(25,5))

plt.plot(data['HIGH '])
plt.show()

# %%
data['DATE']=pd.to_datetime(data['Date '])
data.drop(['Date '], axis = 1)
# Out:
#     series    OPEN    HIGH     LOW   PREV. CLOSE     ltp   close    vwap   \
# 0        EQ  401.75  401.75  387.50        417.25  395.75  394.00  394.41
# 1        EQ  431.85  431.85  414.75        437.10  418.40  417.25  423.93
# 2        EQ  458.50  458.50  435.00        447.60  437.90  437.10  443.17
# 3        EQ  452.95  454.25  444.55        454.05  448.80  447.60  449.27
# 4        EQ  445.00  457.35  440.45        459.75  453.95  454.05  452.40
# ..      ...     ...     ...     ...           ...     ...     ...     ...
# 491      EQ   85.60   87.65   82.20         89.75   82.60   82.95   84.99
# 492      EQ   81.90   94.15   78.05         88.00   90.50   89.75   87.17
# 493      EQ   91.10   94.90   84.10         98.90   88.95   88.00   89.33
# 494      EQ  104.85  106.50   97.80        105.70   98.35   98.90  101.88
# 495      EQ  109.00  109.85  104.25        114.20  104.90  105.70  107.19
#
#      52W H   52W L     VOLUME              VALUE   No of trades        DATE
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=496, step=1)

# %%
data=data.set_index('DATE',drop=True)

# %%
data
# Out:
#                   Date  series    OPEN    HIGH     LOW   PREV. CLOSE     ltp   \
# DATE
# 2022-03-07  07-Mar-2022      EQ  401.75  401.75  387.50        417.25  395.75
# 2022-03-04  04-Mar-2022      EQ  431.85  431.85  414.75        437.10  418.40
# 2022-03-03  03-Mar-2022      EQ  458.50  458.50  435.00        447.60  437.90
# 2022-03-02  02-Mar-2022      EQ  452.95  454.25  444.55        454.05  448.80
# 2022-02-28  28-Feb-2022      EQ  445.00  457.35  440.45        459.75  453.95
# ...                 ...     ...     ...     ...     ...           ...     ...
# 2020-03-16  16-Mar-2020      EQ   85.60   87.65   82.20         89.75   82.60
# 2020-03-13  13-Mar-2020      EQ   81.90   94.15   78.05         88.00   90.50
# 2020-03-12  12-Mar-2020      EQ   91.10   94.90   84.10         98.90   88.95
# 2020-03-11  11-Mar-2020      EQ  104.85  106.50   97.80        105.70   98.35
# 2020-03-09  09-Mar-2020      EQ  109.00  109.85  104.25        114.20  104.90
#
# ...

# %%
data.index
# Out:
# DatetimeIndex(['2022-03-07', '2022-03-04', '2022-03-03', '2022-03-02',
#                '2022-02-28', '2022-02-25', '2022-02-24', '2022-02-23',
#                '2022-02-22', '2022-02-21',
#                ...
#                '2020-03-23', '2020-03-20', '2020-03-19', '2020-03-18',
#                '2020-03-17', '2020-03-16', '2020-03-13', '2020-03-12',
#                '2020-03-11', '2020-03-09'],
#               dtype='datetime64[ns]', name='DATE', length=496, freq=None)

# %%
data['HIGH '].plot(xlim=['2020-03-01','2022-03-15'],figsize=(12,4),c='blue')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
fig, axes = plt.subplots(3,1,figsize=(20, 10),facecolor='white')
sns.lineplot(data=data,x='DATE',y='OPEN ',palette='Blues',ax=axes[0])
sns.lineplot(data=data,x='DATE',y='HIGH ',palette='Red',ax=axes[1])
sns.lineplot(data=data,x='DATE',y='LOW ',palette='green',ax=axes[2])
# Out:
# <AxesSubplot:xlabel='DATE', ylabel='LOW '>

# %%
data.head()
# Out:
#                   Date  series    OPEN    HIGH     LOW   PREV. CLOSE     ltp   \
# DATE
# 2022-03-07  07-Mar-2022      EQ  401.75  401.75  387.50        417.25  395.75
# 2022-03-04  04-Mar-2022      EQ  431.85  431.85  414.75        437.10  418.40
# 2022-03-03  03-Mar-2022      EQ  458.50  458.50  435.00        447.60  437.90
# 2022-03-02  02-Mar-2022      EQ  452.95  454.25  444.55        454.05  448.80
# 2022-02-28  28-Feb-2022      EQ  445.00  457.35  440.45        459.75  453.95
#
#             close    vwap   52W H   52W L    VOLUME              VALUE   \
# DATE
# 2022-03-07  394.00  394.41   536.7  268.45  44836205  17,684,025,650.05
# 2022-03-04  417.25  423.93   536.7  268.45  38765185  16,433,838,263.50
# 2022-03-03  437.10  443.17   536.7  268.45  29599672  13,117,748,918.25
# 2022-03-02  447.60  449.27   536.7  268.45  25791134  11,587,137,992.70
# 2022-02-28  454.05  452.40   536.7  268.45  34475468  15,596,569,802.85
#
#             No of trades
# DATE
# ...

# %%
data.resample(rule='M').max()['OPEN '].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# ## moving average

# %%
data['OPEN '].plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
data['OPEN MA']=data['OPEN '].rolling(window=5,min_periods=1).mean()

# %%
#simple moving average
data[['OPEN MA','OPEN ']].plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# cumulative moving average
data['OPEN CA']=data['OPEN '].expanding().mean()
data[['OPEN CA','OPEN ']].plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
#EWMA
data['OPEN EWMA']=data['OPEN '].ewm(alpha=0.1,adjust=False).mean()
data[['OPEN EWMA','OPEN ']].plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='DATE'>
